# %%
import pandas as pd
import numpy as np
import os
import src.DataWrangling as DataWrangling
from pathlib import Path
PROJECT_ROOT = Path("..").resolve()
PROJECT_ROOT
# Out:
# PosixPath('/home/youssof/Desktop/Sepsis')

# %%
data = DataWrangling.load_data(f"{PROJECT_ROOT}/data/training_data")

# %%
data.keys()
# Out:
# dict_keys(['measurement_observation', 'observation', 'devices', 'measurement_lab', 'proceduresoccurrences', 'measurement_meds', 'SepsisLabel', 'drugsexposure', 'person_demographics_episode'])

# %%
data["measurement_meds"]
# Out:
#          index  visit_occurrence_id   person_id measurement_datetime  \
# 0       200522           1704005512     1765616  2023-05-12 14:00:00
# 1       200523           1704005512     1765616  2023-05-12 16:00:00
# 2       200524           1704005512     1765616  2023-05-12 18:00:00
# 3       200525           1704005512     1765616  2023-05-12 20:00:00
# 4       200526           1704005512     1765616  2023-05-13 00:00:00
# ...        ...                  ...         ...                  ...
# 257744  173847           1464914453  2146982383  2019-12-24 01:00:00
# 257745  173848           1464914453  2146982383  2019-12-24 03:00:00
# 257746  173849           1464914453  2146982383  2019-12-24 05:00:00
# 257747  173850           1464914453  2146982383  2019-12-24 11:00:00
# 257748  173851           1464914453  2146982383  2019-12-24 13:00:00
#
#         Systolic blood pressure  Diastolic blood pressure  Body temperature  \
# 0                           NaN                       NaN              34.8
# 1                           NaN                       NaN              36.0
# 2                           NaN                       NaN              35.6
# 3                           NaN                       NaN              36.7
# 4                           NaN                       NaN              36.6
# ...                         ...                       ...               ...
# 257744                      NaN                       NaN              37.0
# 257745                      NaN                       NaN              37.7
# 257746                      NaN                       NaN              36.5
# 257747                      NaN                       NaN              35.7
# 257748                      NaN                       NaN              36.7
#
#         Respiratory rate  Heart rate  \
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN         NaN
# 3                    NaN         NaN
# 4                    NaN         NaN
# ...                  ...         ...
# 257744               NaN         NaN
# 257745               NaN         NaN
# 257746               NaN         NaN
# 257747               NaN         NaN
# 257748               NaN         NaN
#
#         Measurement of oxygen saturation at periphery  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 257744                                            NaN
# 257745                                            NaN
# 257746                                            NaN
# 257747                                            NaN
# 257748                                            NaN
#
#         Oxygen/Gas total [Pure volume fraction] Inhaled gas
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 257744                                                NaN
# 257745                                                NaN
# 257746                                                NaN
# 257747                                                NaN
# 257748                                                NaN
#
# [257749 rows x 11 columns]

# %%
data_fixed = data["measurement_meds"].copy()
data_fixed["Body temperature"] = data_fixed["Body temperature"].apply(DataWrangling.temperature_fixer)
data_fixed["Heart rate"] = data_fixed["Heart rate"].apply(DataWrangling.heart_rate_fixer)
data_fixed["Respiratory rate"] = data_fixed["Respiratory rate"].apply(DataWrangling.respiration_fixer)
data_fixed["Systolic blood pressure"] = data_fixed["Systolic blood pressure"].apply(DataWrangling.sys_bp_fixer)
data_fixed["Diastolic blood pressure"] = data_fixed["Diastolic blood pressure"].apply(DataWrangling.dias_bp_fixer)
data_fixed["Measurement of oxygen saturation at periphery"] = data_fixed["Measurement of oxygen saturation at periphery"].apply(DataWrangling.oxy_sat_fixer)
data_fixed
# Out:
#          index  visit_occurrence_id   person_id measurement_datetime  \
# 0       200522           1704005512     1765616  2023-05-12 14:00:00
# 1       200523           1704005512     1765616  2023-05-12 16:00:00
# 2       200524           1704005512     1765616  2023-05-12 18:00:00
# 3       200525           1704005512     1765616  2023-05-12 20:00:00
# 4       200526           1704005512     1765616  2023-05-13 00:00:00
# ...        ...                  ...         ...                  ...
# 257744  173847           1464914453  2146982383  2019-12-24 01:00:00
# 257745  173848           1464914453  2146982383  2019-12-24 03:00:00
# 257746  173849           1464914453  2146982383  2019-12-24 05:00:00
# 257747  173850           1464914453  2146982383  2019-12-24 11:00:00
# 257748  173851           1464914453  2146982383  2019-12-24 13:00:00
#
#         Systolic blood pressure  Diastolic blood pressure  Body temperature  \
# 0                           NaN                       NaN              34.8
# 1                           NaN                       NaN              36.0
# 2                           NaN                       NaN              35.6
# 3                           NaN                       NaN              36.7
# 4                           NaN                       NaN              36.6
# ...                         ...                       ...               ...
# 257744                      NaN                       NaN              37.0
# 257745                      NaN                       NaN              37.7
# 257746                      NaN                       NaN              36.5
# 257747                      NaN                       NaN              35.7
# 257748                      NaN                       NaN              36.7
#
#         Respiratory rate  Heart rate  \
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN         NaN
# 3                    NaN         NaN
# 4                    NaN         NaN
# ...                  ...         ...
# 257744               NaN         NaN
# 257745               NaN         NaN
# 257746               NaN         NaN
# 257747               NaN         NaN
# 257748               NaN         NaN
#
#         Measurement of oxygen saturation at periphery  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 257744                                            NaN
# 257745                                            NaN
# 257746                                            NaN
# 257747                                            NaN
# 257748                                            NaN
#
#         Oxygen/Gas total [Pure volume fraction] Inhaled gas
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 257744                                                NaN
# 257745                                                NaN
# 257746                                                NaN
# 257747                                                NaN
# 257748                                                NaN
#
# [257749 rows x 11 columns]

# %%
data_imputed = data_fixed.copy()
data_imputed.drop("Oxygen/Gas total [Pure volume fraction] Inhaled gas",axis=1,inplace=True)
for column in data_imputed.columns:
    data_imputed = DataWrangling.last_observed_imputer(data_imputed,column)
data_imputed
# Out:
#          index  visit_occurrence_id   person_id measurement_datetime  \
# 0       200522           1704005512     1765616  2023-05-12 14:00:00
# 1       200523           1704005512     1765616  2023-05-12 16:00:00
# 2       200524           1704005512     1765616  2023-05-12 18:00:00
# 3       200525           1704005512     1765616  2023-05-12 20:00:00
# 4       200526           1704005512     1765616  2023-05-13 00:00:00
# ...        ...                  ...         ...                  ...
# 257744  173847           1464914453  2146982383  2019-12-24 01:00:00
# 257745  173848           1464914453  2146982383  2019-12-24 03:00:00
# 257746  173849           1464914453  2146982383  2019-12-24 05:00:00
# 257747  173850           1464914453  2146982383  2019-12-24 11:00:00
# 257748  173851           1464914453  2146982383  2019-12-24 13:00:00
#
#         Systolic blood pressure  Diastolic blood pressure  Body temperature  \
# 0                           NaN                       NaN              34.8
# 1                           NaN                       NaN              36.0
# 2                           NaN                       NaN              35.6
# 3                           NaN                       NaN              36.7
# 4                           NaN                       NaN              36.6
# ...                         ...                       ...               ...
# 257744                      NaN                       NaN              37.0
# 257745                      NaN                       NaN              37.7
# 257746                      NaN                       NaN              36.5
# 257747                      NaN                       NaN              35.7
# 257748                      NaN                       NaN              36.7
#
#         Respiratory rate  Heart rate  \
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN         NaN
# 3                    NaN         NaN
# 4                    NaN         NaN
# ...                  ...         ...
# 257744               NaN         NaN
# 257745               NaN         NaN
# 257746               NaN         NaN
# 257747               NaN         NaN
# 257748               NaN         NaN
#
#         Measurement of oxygen saturation at periphery
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 257744                                            NaN
# 257745                                            NaN
# 257746                                            NaN
# 257747                                            NaN
# 257748                                            NaN
#
# [257749 rows x 10 columns]

# %%
data_not_null = data_imputed.dropna().copy()
data_not_null
# Out:
#         index  visit_occurrence_id   person_id measurement_datetime  \
# 85      57648            537992341     2904978  2024-11-06 14:00:00
# 86      57649            537992341     2904978  2024-11-06 15:00:00
# 87      57650            537992341     2904978  2024-11-06 16:00:00
# 88      57651            537992341     2904978  2024-11-06 17:00:00
# 89      57652            537992341     2904978  2024-11-06 18:00:00
# ...       ...                  ...         ...                  ...
# 256927  85454            768142041  2130258284  2024-02-16 08:00:00
# 256928  85455            768142041  2130258284  2024-02-16 09:00:00
# 256929  85456            768142041  2130258284  2024-02-16 10:00:00
# 256930  85457            768142041  2130258284  2024-02-16 11:00:00
# 256931  85458            768142041  2130258284  2024-02-16 12:00:00
#
#         Systolic blood pressure  Diastolic blood pressure  Body temperature  \
# 85                         92.0                      47.0              37.0
# 86                         92.0                      47.0              37.0
# 87                         92.0                      47.0              36.6
# 88                        108.0                      55.0              36.6
# 89                        106.0                      59.0              36.4
# ...                         ...                       ...               ...
# 256927                    110.0                      70.0              35.2
# 256928                    110.0                      70.0              35.2
# 256929                    131.0                     105.0              35.2
# 256930                    131.0                     105.0              35.2
# 256931                    131.0                     105.0              35.2
#
#         Respiratory rate  Heart rate  \
# 85             45.370370  210.377040
# 86             44.921050  208.269560
# 87             45.407770  208.594590
# 88             46.632183  210.091660
# 89             39.796610  207.364410
# ...                  ...         ...
# 256927         39.440678  121.203390
# 256928         44.446280  127.057850
# 256929         45.076270  126.576270
# 256930         38.176470  129.991600
# 256931         35.916668  112.333336
#
#         Measurement of oxygen saturation at periphery
# 85                                          96.555560
# 86                                          93.132070
# 87                                          96.358696
# 88                                          91.337660
# 89                                          94.028305
# ...                                               ...
# 256927                                      97.127120
# 256928                                      97.090910
# 256929                                      97.220340
# 256930                                      98.184875
# 256931                                      97.541664
#
# [115752 rows x 10 columns]

# %%
sepsis_data = data["SepsisLabel"].copy()
sepsis_data["SepsisLabel"].value_counts(normalize=True)
# Out:
# SepsisLabel
# 0    0.979274
# 1    0.020726
# Name: proportion, dtype: float64

# %%
sepsis_data[sepsis_data["person_id"].isin(data_not_null["person_id"].tolist())]["SepsisLabel"].value_counts(normalize=True)
# Out:
# SepsisLabel
# 0    0.982477
# 1    0.017523
# Name: proportion, dtype: float64
